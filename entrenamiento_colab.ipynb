# %% [markdown]
# # Tiny Stories JEPA Demo Training
# Este notebook descarga e instala Rust, clona el repositorio `ssm-latent-rs`, y ejecuta el entrenamiento de la demo de Tiny Stories.

# %%
# 1. Instalar Rust
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y

# Agregar Rust al PATH del entorno de ejecución
import os
os.environ['PATH'] += ":/root/.cargo/bin"

# %%
# 2. Clonar el repositorio
# !git clone https://github.com/emanuelbertey/ssm-latent-rs.git
# %cd ssm-latent-rs

# %%
# 3. Compilar el proyecto en modo release
# !cargo build --release --package tiny-stories-jepa-demo

# %%
# 4. Ejecutar el proyecto (entrenamiento y generacion)
# !cargo run --release --package tiny-stories-jepa-demo
